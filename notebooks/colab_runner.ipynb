# %% [markdown]
# # Synthetic Smoke Runner
#
# This notebook runs the same CLI used locally. Synthetic outputs are for software verification only, not research results.

# %%
# %pip install -e .

# %%
# !python -m emotion_project.cli smoke --config configs/synthetic_smoke.json
